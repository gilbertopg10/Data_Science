# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv("indeed_data_science_jobs.csv")

print(df.head(20))
# Out:
#     Position                                          Job Title  \
# 0          1                                     Data Scientist
# 1          2  Senior Artificial Intelligence Researcher for ...
# 2          3                              Senior Data Scientist
# 3          4                                     Data Scientist
# 4          5                                     Data Scientist
# 5          6                                     Data Scientist
# 6          7                   Business Data Scientist/Engineer
# 7          8                                   Data Scientist I
# 8          9                                     Data Scientist
# 9         10                           Associate Data Scientist
# 10        11                                     Data Scientist
# 11        12                                     Data Scientist
# 12        13                                   Systems Engineer
# 13        14                              Senior Data Scientist
# 14        15       Scientist, Data Science Analytics & Insights
# 15        16                                     DATA SCIENTIST
# 16        17                                     Data Scientist
# 17        18                                     Data Scientist
# 18        19                          Data Scientist (contract)
# 19        20                                   Data Scientist I
#
#                                            Company  \
# 0                                      Robert Half
# 1   Johns Hopkins Applied Physics Laboratory (APL)
# 2                Modern Technology Solutions, Inc.
# 3                         Twitch Interactive, Inc.
# 4                US Office of Personnel Management
# 5                                   MagicSchool AI
# 6                                            Apple
# 7                                     GM Financial
# 8                                 Ropes & Gray LLP
# 9                                             UPMC
# 10                         Long Beach City College
# 11            National Space Defense Center (NSDC)
# 12                            Patelco Credit Union
# 13                      Amazee Global Ventures Inc
# 14                               Johnson & Johnson
# 15                                       TriHealth
# 16                           Northwestern Medicine
# 17                               Johnson & Johnson
# 18                                             JnJ
# 19                                    Kandu Health
#
#                                              Location  \
# 0                     Remote in Los Angeles, CA 90024
# 1                                    Laurel, MD 20723
# 2                                Huntsville, AL 35895
# 3                                         Seattle, WA
# 4                                              Remote
# 5                                  Remote in Colorado
# 6                                          Austin, TX
# 7                       Hybrid work in Fort Worth, TX
# 8                     Hybrid work in Boston, MA 02199
# 9                 Pittsburgh, PA 15219 \n(Bluff area)
# 10     Long Beach, CA 90808 \n(Lakewood Village area)
# 11  Colorado Springs, CO 80906 \n(Southwest Colora...
# 12                                   Dublin, CA 94568
# 13                                         Dallas, TX
# 14                                     Titusville, NJ
# 15                                     Cincinnati, OH
# 16           Chicago, IL 60611 \n(Streeterville area)
# 17                                     Titusville, NJ
# 18                                        Raritan, NJ
# 19                  Hybrid work in Campbell, CA 95008
#
#                         Salary  \
# 0   $120,000 - $140,000 a year
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4   $103,409 - $167,336 a year
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8   $125,000 - $150,000 a year
# 9                          NaN
# 10  $106,779 - $145,487 a year
# 11   $89,128 - $137,784 a year
# 12  $115,764 - $120,000 a year
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
#
#                                     Short Description  \
# 0   The ideal candidate should be highly skilled i...
# 1   As a member of our research team, you will con...
# 2   Utilize machine learning techniques, algorithm...
# 3   Conduct ad-hoc analyses, build robust automate...
# 4   Develops and maintains analytics product proje...
# 5   Enable smarter business processes by utilizing...
# 6   You will work closely with multi-functional te...
# 7   The Data Scientist I is the subject matter exp...
# 8   You will work with lawyers, behavioral scienti...
# 9   Design, develop, and implement health care ana...
# 10  Develops an understanding of opportunities, co...
# 11  Knowledge of data science techniques and techn...
# 12  Patelco Credit Union is a not-for-profit credi...
# 13  Skilled in creating clear, data-driven present...
# 14  Demonstrate emerging scientific and technologi...
# 15  Analyze and model structured as well as semi s...
# 16  The data engineers/scientists use their broad ...
# 17  In this role you will be someone who stays on ...
# 18  This role will provide support for the manufac...
# 19  Collaborate closely with research and clinical...
#
#                       Posted At  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13  Employer\nActive 4 days ago
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
#
#                                              Job link
# 0   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3   https://www.indeed.com/rc/clk?jk=4593a41913786...
# 4   https://www.indeed.com/rc/clk?jk=d393197b7bc42...
# 5   https://www.indeed.com/rc/clk?jk=258a205f5e303...
# 6   https://www.indeed.com/rc/clk?jk=563bac05a8878...
# 7   https://www.indeed.com/rc/clk?jk=85b9540e6b08e...
# 8   https://www.indeed.com/rc/clk?jk=fec3590ced9d6...
# 9   https://www.indeed.com/rc/clk?jk=f5de21340edf2...
# 10  https://www.indeed.com/rc/clk?jk=d8685d06c8699...
# 11  https://www.indeed.com/rc/clk?jk=c93a5b5e6a21f...
# 12  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 13  https://www.indeed.com/rc/clk?jk=1d185434ecff3...
# 14  https://www.indeed.com/rc/clk?jk=e1714afb1b42b...
# 15  https://www.indeed.com/rc/clk?jk=ba77d2dbf2ce3...
# 16  https://www.indeed.com/rc/clk?jk=8cb757bd03153...
# 17  https://www.indeed.com/rc/clk?jk=baaa822d0fc6f...
# 18  https://www.indeed.com/rc/clk?jk=98ba48d52b95b...
# 19  https://www.indeed.com/rc/clk?jk=795023c034e63...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Position           200 non-null    int64
#  1   Job Title          200 non-null    object
#  2   Company            200 non-null    object
#  3   Location           200 non-null    object
#  4   Salary             62 non-null     object
#  5   Short Description  200 non-null    object
#  6   Posted At          16 non-null     object
#  7   Job link           200 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 12.6+ KB

# %%
import re

df_2 = df.copy()


def classify_job_title(title):
    title = title.lower()  # Convert to lowercase for easier matching

    # Regex patterns for different roles
    if re.search(r'scien', title):
        return 'Data Scientist'
    elif re.search(r'analy', title):
        return 'Data Analyst'
    elif re.search(r'engineer', title):
        return 'Data Engineer'
    else:
        return 'Other'

# Apply the function to classify job titles
df_2['Job Profile'] = df_2['Job Title'].apply(classify_job_title)

# %%
print(df_2['Job Profile'].unique)
# Out:
# <bound method Series.unique of 0      Data Scientist
# 1      Data Scientist
# 2      Data Scientist
# 3      Data Scientist
# 4      Data Scientist
#             ...
# 195    Data Scientist
# 196    Data Scientist
# 197    Data Scientist
# 198             Other
# 199    Data Scientist
# Name: Job Profile, Length: 200, dtype: object>

# %%
# Function to extract the minimum numeric salary
def extract_min_salary(salary):
    if pd.isna(salary):  # Handle NaN values
        return None
    
    # Use regex to extract all numeric values from the salary string
    numeric_values = re.findall(r'\d+', salary)
    
    if numeric_values:
        # Convert to integers and return the minimum value
        min_salary = min(map(int, numeric_values))
        return min_salary
    else:
        return None  # Return None if no numeric value is found

# Apply the function to the Salary column
df_2['Salary'] = df_2['Salary'].apply(extract_min_salary)

# Convert the Salary column to numeric, forcing errors to NaN
df_2['Salary'] = pd.to_numeric(df_2['Salary'], errors='coerce')

# Convert salary values from thousands to actual scale (e.g., 103 -> 103000)
df_2['Salary'] = df_2['Salary'] * 1000

# Fill NaN values in the Salary column with the average salary
df_2['Salary'].fillna(70000, inplace=True)

# Round the 'Salary' column to two decimal places
df_2['Salary'] = df_2['Salary'].round(2)
# Out:
# C:\Users\gpg90\AppData\Local\Temp\ipykernel_19244\2226795343.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2['Salary'].fillna(70000, inplace=True)

# %%
# Drop the 'Posted At' and 'Short Description' columns
df_2.drop(columns=['Posted At', 'Short Description'], inplace=True)

# Display the DataFrame to confirm the columns have been dropped
print(df_2.head())
# Out:
#    Position                                          Job Title  \
# 0         1                                     Data Scientist
# 1         2  Senior Artificial Intelligence Researcher for ...
# 2         3                              Senior Data Scientist
# 3         4                                     Data Scientist
# 4         5                                     Data Scientist
#
#                                           Company  \
# 0                                     Robert Half
# 1  Johns Hopkins Applied Physics Laboratory (APL)
# 2               Modern Technology Solutions, Inc.
# 3                        Twitch Interactive, Inc.
# 4               US Office of Personnel Management
#
#                           Location    Salary  \
# 0  Remote in Los Angeles, CA 90024       0.0
# 1                 Laurel, MD 20723   70000.0
# 2             Huntsville, AL 35895   70000.0
# 3                      Seattle, WA   70000.0
# 4                           Remote  103000.0
#
#                                             Job link     Job Profile
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  Data Scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  Data Scientist
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  Data Scientist
# 3  https://www.indeed.com/rc/clk?jk=4593a41913786...  Data Scientist
# 4  https://www.indeed.com/rc/clk?jk=d393197b7bc42...  Data Scientist

# %%
# Function to extract city and state from the location string
def extract_city_state(location):
    if pd.isna(location):
        return pd.Series([None, None])
    
    # Regex to capture city and state
    match = re.search(r'(?P<city>[A-Za-z\s]+),\s*(?P<state>[A-Z]{2})', location)
    
    if match:
        return pd.Series([match.group('city').strip(), match.group('state')])
    else:
        return pd.Series([None, None])

# Apply the function and create new columns
df_2[['City', 'State']] = df_2['Location'].apply(extract_city_state)

# Drop the original Location column if no longer needed
df_2.drop(columns=['Location'], inplace=True)

# Display the updated DataFrame
print(df_2.head())
# Out:
#    Position                                          Job Title  \
# 0         1                                     Data Scientist
# 1         2  Senior Artificial Intelligence Researcher for ...
# 2         3                              Senior Data Scientist
# 3         4                                     Data Scientist
# 4         5                                     Data Scientist
#
#                                           Company    Salary  \
# 0                                     Robert Half       0.0
# 1  Johns Hopkins Applied Physics Laboratory (APL)   70000.0
# 2               Modern Technology Solutions, Inc.   70000.0
# 3                        Twitch Interactive, Inc.   70000.0
# 4               US Office of Personnel Management  103000.0
#
#                                             Job link     Job Profile  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  Data Scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  Data Scientist
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  Data Scientist
# 3  https://www.indeed.com/rc/clk?jk=4593a41913786...  Data Scientist
# 4  https://www.indeed.com/rc/clk?jk=d393197b7bc42...  Data Scientist
#
#                     City State
# 0  Remote in Los Angeles    CA
# 1                 Laurel    MD
# 2             Huntsville    AL
# 3                Seattle    WA
# 4                   None  None

# %%
# Save the final DataFrame to a CSV file
df_2.to_csv('final_job_data.csv', index=False)
